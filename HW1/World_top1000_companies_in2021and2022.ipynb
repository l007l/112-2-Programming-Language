# %%
import pandas as pd

data2021 = pd.read_csv('C:/Users/user/PL/HW1/fortune1000_companies_2021.csv')
data2022 = pd.read_csv('C:/Users/user/PL/HW1/fortune1000_companies_2022.csv')

# %%
campanies2021 = set(data2021.iloc[:, 2])
campanies2022 = set(data2022.iloc[:, 1])

# %%
type(campanies2021)
# Out:
# set

# %%
type(campanies2022)
# Out:
# set

# %% [markdown]
# 排序顯示結果

# %%
difference_set = sorted(campanies2021.difference(campanies2022))
difference2_set = sorted(campanies2022.difference(campanies2021))
intersection_set = sorted(campanies2021.intersection(campanies2022))
union_set = sorted(campanies2021.union(campanies2022))

# %%
print("差集，2021年度有進世界公司財富榜頭1000名但沒進2022年度的公司有：",difference_set)
# Out:
# 差集，2021年度有進世界公司財富榜頭1000名但沒進2022年度的公司有： ['AAR', 'Air Lease', 'Alexion Pharmaceuticals', 'Alliance Data Systems', 'American International Group', 'Amneal Pharmaceuticals', 'Archer Daniels Midland (ADM)', 'Arcosa', 'B&G Foods', 'BGC Partners', 'BOK Financial', 'BioMarin Pharmaceutical', 'Blackstone Group', 'CDK Global', 'CIT Group', 'Carpenter Technology', 'Clearwater Paper', 'Colfax', 'ContextLogic', 'Cooper', 'Cooper Tire & Rubber', 'Core-Mark Holding', 'CoreCivic', 'CoreLogic', 'Covanta Holding', 'Crane', 'Discovery', 'Echo Global Logistics', 'EchoStar', 'Edgewell Personal Care', 'Enable Midstream Partners', 'F5 Networks', 'First Citizens BancShares', 'Flagstar Bancorp', 'Genesis Healthcare', 'Greenbrier', 'Hain Celestial Group', 'Healthpeak Properties', 'Hexion', 'Hilltop Holdings', 'HollyFrontier', 'International Business Machines', 'Itron', 'Kansas City Southern', 'Kennametal', 'Korn Ferry', 'Laureate Education', 'Lululemon Athletica', 'Magellan Health', 'Mahwah Bergen Retail Group', 'Mednax', 'Meredith', 'Michaels', 'Modine Manufacturing', 'Navistar International', 'PAE', 'PPD', 'PRA Health Sciences', "People's United Financial", 'Perspecta', 'Revlon', 'Scientific Games', 'Seagen', 'Sempra Energy', 'StoneX', 'Synovus Financial', 'TCF Financial', 'Teledyne FLIR', 'Terminix Global Holdings', 'Trinity Industries', 'Triple-S Management', 'Triumph Group', 'Unisys', 'United Parcel Service', 'Universal', 'Univision Communications', 'Vail Resorts', 'Varian Medical Systems', 'ViacomCBS', 'Westlake Chemical', 'Windstream Holdings II', 'Zurn Water Solutions']

# %%
print("差集，2022年度有進世界公司財富榜頭1000名但沒進2021年度的公司有：",difference2_set)
# Out:
# 差集，2022年度有進世界公司財富榜頭1000名但沒進2021年度的公司有： ['1-800-Flowers.com', 'AIG', 'AMC Entertainment Holdings', 'Acushnet Holdings', 'AdaptHealth', 'Alight', 'Alpha Metallurgical Resources', 'Annaly Capital Management', 'AppLovin', 'Arch Resources', 'Archer Daniels Midland', 'Ares Management', 'Atkore', 'Blackstone', 'Bread Financial Holdings', 'Bright Health Group', 'Callaway Golf', 'Century Aluminum', 'Change Healthcare', 'Coinbase Global', 'Concentrix', 'Cooper Cos.', 'Core & Main', 'Coterra Energy', 'Cowen', 'Crane Holdings', 'Crocs', 'CrossAmerica Partners', 'DocuSign', 'Dun & Bradstreet Holdings', 'Element Solutions', 'Encore Wire', 'Enovis', 'Etsy', 'F5', 'GXO Logistics', 'Genesco', 'Genesis Energy', 'HF Sinclair', 'Hilton Grand Vacations', 'Host Hotels & Resorts', 'IBM', 'Jackson Financial', 'Kaiser Aluminum', 'Kontoor Brands', 'Liberty Energy', 'Light & Wonder', 'Lululemon athletica', 'Marvell Technology', 'Mattress Firm Group', 'Moderna', 'Mutual of America Life Insurance', 'New Residential Investment', 'Olympic Steel', 'Paramount Global', 'Party City Holdco', 'Peloton Interactive', 'Pinterest', 'Pure Storage', 'Roku', 'SM Energy', 'Saia', 'Schnitzer Steel Industries', 'Sempra', 'Signature Bank', 'Spirit Airlines', 'StoneX Group', 'Sun Communities', 'TPG', 'TrueBlue', 'Twilio', 'UPS', 'Univision Communciations', "Victoria's Secret", 'Vista Outdoor', 'Vizio Holding', 'Vroom', 'Warner Bros. Discovery', 'WeWork', 'Westlake', 'Wolverine World Wide', 'eXp World Holdings']

# %%
print("交集，2021及2022年度均有進世界公司財富榜頭1000名的公司有：",intersection_set)
# Out:
# 交集，2021及2022年度均有進世界公司財富榜頭1000名的公司有： ['3M', 'A-Mark Precious Metals', 'A.O. Smith', 'ABM Industries', 'ADT', 'AECOM', 'AES', 'AGCO', 'AMC Networks', 'AMN Healthcare Services', 'APA', 'APi Group', 'ARKO', 'ASGN', 'AT&T', 'AbbVie', 'Abbott Laboratories', 'Abercrombie & Fitch', 'Academy Sports and Outdoors', 'Acadia Healthcare', 'Activision Blizzard', 'Acuity Brands', 'Adobe', 'Advance Auto Parts', 'Advanced Micro Devices', 'Advantage Solutions', 'Aerojet Rocketdyne Holdings', 'Affiliated Managers Group', 'Aflac', 'Agilent Technologies', 'Air Products & Chemicals', 'Airbnb', 'Akamai Technologies', 'Alaska Air Group', 'Albemarle', 'Albertsons', 'Alcoa', 'Alexandria Real Estate Equities', 'Align Technology', 'Alleghany', 'Allegheny Technologies', 'Alliant Energy', 'Allison Transmission Holdings', 'Allstate', 'Ally Financial', 'Alphabet', 'Altice USA', 'Altria Group', 'Amazon', 'Amedisys', 'Amerco', 'Ameren', 'American Airlines Group', 'American Axle & Manufacturing', 'American Eagle Outfitters', 'American Electric Power', 'American Equity Investment Life Holding', 'American Express', 'American Family Insurance Group', 'American Financial Group', 'American National Group', 'American Tower', 'American Water Works', 'Americold Realty Trust', 'Ameriprise Financial', 'AmerisourceBergen', 'Ametek', 'Amgen', 'Amica Mutual Insurance', 'Amkor Technology', 'Amphenol', 'Analog Devices', 'Andersons', 'Antero Resources', 'Anthem', 'Apollo Global Management', 'Apple', 'Applied Industrial Technologies', 'Applied Materials', 'AptarGroup', 'Aramark', 'ArcBest', 'Arconic', 'Arista Networks', 'Arrow Electronics', 'Arthur J. Gallagher', 'Asbury Automotive Group', 'Ashland Global Holdings', 'Assurant', 'Atlas Air Worldwide Holdings', 'Atmos Energy', 'Auto-Owners Insurance', 'AutoNation', 'AutoZone', 'Autodesk', 'Autoliv', 'Automatic Data Processing', 'AvalonBay Communities', 'Avantor', 'Avaya Holdings', 'Avery Dennison', 'Avient', 'Avis Budget Group', 'Avnet', "BJ's Wholesale Club", 'BWX Technologies', 'Baker Hughes', 'Ball', 'Bank of America', 'Bank of New York Mellon', 'Bath & Body Works', 'Baxter International', 'Beacon Roofing Supply', 'Beazer Homes USA', 'Becton Dickinson', 'Bed Bath & Beyond', 'Belden', 'Benchmark Electronics', 'Berkshire Hathaway', 'Berry Global Group', 'Best Buy', 'Big Lots', 'Bio-Rad Laboratories', 'Biogen', 'BlackRock', 'Block', "Bloomin' Brands", 'BlueLinx Holdings', 'Boeing', 'Boise Cascade', 'Booking Holdings', 'Booz Allen Hamilton Holding', 'BorgWarner', 'Boston Properties', 'Boston Scientific', 'Boyd Gaming', 'BrightView Holdings', 'Brighthouse Financial', "Brink's", 'Brinker International', 'Bristol-Myers Squibb', 'Broadcom', 'Broadridge Financial Solutions', 'Brookdale Senior Living', 'Brown & Brown', 'Brown-Forman', 'Bruker', 'Brunswick', 'Builders FirstSource', 'Burlington Stores', 'C.H. Robinson Worldwide', 'CACI International', 'CBRE Group', 'CDW', 'CF Industries Holdings', 'CHS', 'CME Group', 'CMS Energy', 'CNO Financial Group', 'CSX', 'CUNA Mutual Group', 'CVS Health', 'Cabot', 'Cadence Design Systems', 'Caesars Entertainment', 'Caleres', 'Calumet Specialty Products Partners', 'Campbell Soup', 'Camping World Holdings', 'Capital One Financial', 'CarMax', 'Cardinal Health', 'Carlisle', 'Carlyle Group', 'Carrier Global', "Carter's", 'Carvana', "Casey's General Stores", 'Catalent', 'Caterpillar', 'Cboe Global Markets', 'Celanese', 'Centene', 'CenterPoint Energy', 'Central Garden & Pet', 'Century Communities', 'Cerner', 'ChampionX', 'Charles River Laboratories International', 'Charles Schwab', 'Charter Communications', 'Cheesecake Factory', 'Chemed', 'Chemours', 'Cheniere Energy', 'Chesapeake Energy', 'Chevron', 'Chewy', 'Chipotle Mexican Grill', 'Church & Dwight', 'Ciena', 'Cigna', 'Cincinnati Financial', 'Cintas', 'Cisco Systems', 'Citigroup', 'Citizens Financial Group', 'Citrix Systems', 'Clean Harbors', 'Clear Channel Outdoor Holdings', 'Cleveland-Cliffs', 'Clorox', 'Coca-Cola', 'Coca-Cola Consolidated', 'Cognizant ...

# %%
print("聯集，2021或2022年度有進世界公司財富榜頭1000名的公司有：",intersection_set)
# Out:
# 聯集，2021或2022年度有進世界公司財富榜頭1000名的公司有： ['3M', 'A-Mark Precious Metals', 'A.O. Smith', 'ABM Industries', 'ADT', 'AECOM', 'AES', 'AGCO', 'AMC Networks', 'AMN Healthcare Services', 'APA', 'APi Group', 'ARKO', 'ASGN', 'AT&T', 'AbbVie', 'Abbott Laboratories', 'Abercrombie & Fitch', 'Academy Sports and Outdoors', 'Acadia Healthcare', 'Activision Blizzard', 'Acuity Brands', 'Adobe', 'Advance Auto Parts', 'Advanced Micro Devices', 'Advantage Solutions', 'Aerojet Rocketdyne Holdings', 'Affiliated Managers Group', 'Aflac', 'Agilent Technologies', 'Air Products & Chemicals', 'Airbnb', 'Akamai Technologies', 'Alaska Air Group', 'Albemarle', 'Albertsons', 'Alcoa', 'Alexandria Real Estate Equities', 'Align Technology', 'Alleghany', 'Allegheny Technologies', 'Alliant Energy', 'Allison Transmission Holdings', 'Allstate', 'Ally Financial', 'Alphabet', 'Altice USA', 'Altria Group', 'Amazon', 'Amedisys', 'Amerco', 'Ameren', 'American Airlines Group', 'American Axle & Manufacturing', 'American Eagle Outfitters', 'American Electric Power', 'American Equity Investment Life Holding', 'American Express', 'American Family Insurance Group', 'American Financial Group', 'American National Group', 'American Tower', 'American Water Works', 'Americold Realty Trust', 'Ameriprise Financial', 'AmerisourceBergen', 'Ametek', 'Amgen', 'Amica Mutual Insurance', 'Amkor Technology', 'Amphenol', 'Analog Devices', 'Andersons', 'Antero Resources', 'Anthem', 'Apollo Global Management', 'Apple', 'Applied Industrial Technologies', 'Applied Materials', 'AptarGroup', 'Aramark', 'ArcBest', 'Arconic', 'Arista Networks', 'Arrow Electronics', 'Arthur J. Gallagher', 'Asbury Automotive Group', 'Ashland Global Holdings', 'Assurant', 'Atlas Air Worldwide Holdings', 'Atmos Energy', 'Auto-Owners Insurance', 'AutoNation', 'AutoZone', 'Autodesk', 'Autoliv', 'Automatic Data Processing', 'AvalonBay Communities', 'Avantor', 'Avaya Holdings', 'Avery Dennison', 'Avient', 'Avis Budget Group', 'Avnet', "BJ's Wholesale Club", 'BWX Technologies', 'Baker Hughes', 'Ball', 'Bank of America', 'Bank of New York Mellon', 'Bath & Body Works', 'Baxter International', 'Beacon Roofing Supply', 'Beazer Homes USA', 'Becton Dickinson', 'Bed Bath & Beyond', 'Belden', 'Benchmark Electronics', 'Berkshire Hathaway', 'Berry Global Group', 'Best Buy', 'Big Lots', 'Bio-Rad Laboratories', 'Biogen', 'BlackRock', 'Block', "Bloomin' Brands", 'BlueLinx Holdings', 'Boeing', 'Boise Cascade', 'Booking Holdings', 'Booz Allen Hamilton Holding', 'BorgWarner', 'Boston Properties', 'Boston Scientific', 'Boyd Gaming', 'BrightView Holdings', 'Brighthouse Financial', "Brink's", 'Brinker International', 'Bristol-Myers Squibb', 'Broadcom', 'Broadridge Financial Solutions', 'Brookdale Senior Living', 'Brown & Brown', 'Brown-Forman', 'Bruker', 'Brunswick', 'Builders FirstSource', 'Burlington Stores', 'C.H. Robinson Worldwide', 'CACI International', 'CBRE Group', 'CDW', 'CF Industries Holdings', 'CHS', 'CME Group', 'CMS Energy', 'CNO Financial Group', 'CSX', 'CUNA Mutual Group', 'CVS Health', 'Cabot', 'Cadence Design Systems', 'Caesars Entertainment', 'Caleres', 'Calumet Specialty Products Partners', 'Campbell Soup', 'Camping World Holdings', 'Capital One Financial', 'CarMax', 'Cardinal Health', 'Carlisle', 'Carlyle Group', 'Carrier Global', "Carter's", 'Carvana', "Casey's General Stores", 'Catalent', 'Caterpillar', 'Cboe Global Markets', 'Celanese', 'Centene', 'CenterPoint Energy', 'Central Garden & Pet', 'Century Communities', 'Cerner', 'ChampionX', 'Charles River Laboratories International', 'Charles Schwab', 'Charter Communications', 'Cheesecake Factory', 'Chemed', 'Chemours', 'Cheniere Energy', 'Chesapeake Energy', 'Chevron', 'Chewy', 'Chipotle Mexican Grill', 'Church & Dwight', 'Ciena', 'Cigna', 'Cincinnati Financial', 'Cintas', 'Cisco Systems', 'Citigroup', 'Citizens Financial Group', 'Citrix Systems', 'Clean Harbors', 'Clear Channel Outdoor Holdings', 'Cleveland-Cliffs', 'Clorox', 'Coca-Cola', 'Coca-Cola Consolidated', 'Cognizant  ...
