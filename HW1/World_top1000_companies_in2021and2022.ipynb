# %%
import pandas as pd

data2021 = pd.read_csv('C:/Users/user/PL/HW1/fortune1000_companies_2021.csv')
data2022 = pd.read_csv('C:/Users/user/PL/HW1/fortune1000_companies_2022.csv')

# %%
campanies2021 = set(data2021.iloc[:, 2])
campanies2022 = set(data2022.iloc[:, 1])

# %%
type(campanies2021)
# Out:
# set

# %%
type(campanies2022)
# Out:
# set

# %%
difference_set = campanies2021.difference(campanies2022)
intersection_set = campanies2021.intersection(campanies2022)
union_set = campanies2021.union(campanies2022)

# %%
print("差集，2021年度有進世界公司財富榜頭1000名但沒進2022年度的公司有：",difference_set)
# Out:
# 差集，2021年度有進世界公司財富榜頭1000名但沒進2022年度的公司有： {'CoreLogic', 'Synovus Financial', 'United Parcel Service', 'Carpenter Technology', 'PPD', 'Zurn Water Solutions', 'Air Lease', 'Crane', 'Laureate Education', 'BGC Partners', 'Windstream Holdings II', 'Lululemon Athletica', 'Hexion', 'Hain Celestial Group', 'CDK Global', 'Magellan Health', 'PRA Health Sciences', 'BOK Financial', 'International Business Machines', 'F5 Networks', 'Hilltop Holdings', 'Alliance Data Systems', 'Enable Midstream Partners', 'Cooper Tire & Rubber', 'Westlake Chemical', 'Triumph Group', 'AAR', 'Greenbrier', 'Mahwah Bergen Retail Group', 'Mednax', 'Edgewell Personal Care', 'ViacomCBS', 'Kansas City Southern', 'Echo Global Logistics', 'Cooper', 'Triple-S Management', 'Revlon', 'Healthpeak Properties', 'Varian Medical Systems', 'Korn Ferry', 'Itron', 'Blackstone Group', 'Trinity Industries', 'Genesis Healthcare', 'Univision Communications', 'Perspecta', 'CIT Group', 'ContextLogic', 'Core-Mark Holding', 'Unisys', 'PAE', 'Arc
# ...

# %%
print("交集，2021及2022年度均有進世界公司財富榜頭1000名的公司有：",intersection_set)
# Out:
# 交集，2021及2022年度均有進世界公司財富榜頭1000名的公司有： {'H.B. Fuller', 'Walmart', 'Advance Auto Parts', 'D.R. Horton', 'Netflix', 'ManpowerGroup', 'FMC', 'Toll Brothers', 'Pfizer', 'Align Technology', 'AptarGroup', 'Edison International', 'G-III Apparel Group', 'Ryerson Holding', 'Central Garden & Pet', 'Corteva', 'Live Nation Entertainment', 'Silgan Holdings', 'Meritage Homes', 'NortonLifeLock', 'Crown Holdings', 'PC Connection', 'Primerica', 'Agilent Technologies', 'FedEx', 'Freeport-McMoRan', 'Uber Technologies', 'Cabot', 'Graham Holdings', 'Dentsply Sirona', 'Hyster-Yale Materials Handling', 'IDEXX Laboratories', 'Massachusetts Mutual Life Insurance', 'Avnet', 'MDU Resources Group', 'A-Mark Precious Metals', 'IAC/InterActiveCorp', 'Palo Alto Networks', 'Nasdaq', 'eBay', 'Owens & Minor', 'Rackspace Technology', 'Vishay Intertechnology', 'Assurant', 'Stericycle', 'Resolute Forest Products', 'Principal Financial', 'XPO Logistics', 'Oracle', 'PVH', 'Centene', 'Truist Financial', 'NiSource', 'Griffon', 
# ...

# %%
print("聯集，2021或2022年度有進世界公司財富榜頭1000名的公司有：",intersection_set)
# Out:
# 聯集，2021或2022年度有進世界公司財富榜頭1000名的公司有： {'H.B. Fuller', 'Walmart', 'Advance Auto Parts', 'D.R. Horton', 'Netflix', 'ManpowerGroup', 'FMC', 'Toll Brothers', 'Pfizer', 'Align Technology', 'AptarGroup', 'Edison International', 'G-III Apparel Group', 'Ryerson Holding', 'Central Garden & Pet', 'Corteva', 'Live Nation Entertainment', 'Silgan Holdings', 'Meritage Homes', 'NortonLifeLock', 'Crown Holdings', 'PC Connection', 'Primerica', 'Agilent Technologies', 'FedEx', 'Freeport-McMoRan', 'Uber Technologies', 'Cabot', 'Graham Holdings', 'Dentsply Sirona', 'Hyster-Yale Materials Handling', 'IDEXX Laboratories', 'Massachusetts Mutual Life Insurance', 'Avnet', 'MDU Resources Group', 'A-Mark Precious Metals', 'IAC/InterActiveCorp', 'Palo Alto Networks', 'Nasdaq', 'eBay', 'Owens & Minor', 'Rackspace Technology', 'Vishay Intertechnology', 'Assurant', 'Stericycle', 'Resolute Forest Products', 'Principal Financial', 'XPO Logistics', 'Oracle', 'PVH', 'Centene', 'Truist Financial', 'NiSource', 'Griffon', '
# ...
