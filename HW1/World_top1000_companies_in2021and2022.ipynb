# %%
import pandas as pd

data2021 = pd.read_csv('C:/Users/user/PL/HW1/fortune1000_companies_2021.csv')
data2022 = pd.read_csv('C:/Users/user/PL/HW1/fortune1000_companies_2022.csv')

# %%
campanies2021 = set(data2021.iloc[:, 2])
campanies2022 = set(data2022.iloc[:, 1])

# %%
type(campanies2021)
# Out:
# set

# %%
type(campanies2022)
# Out:
# set

# %%
difference_set = campanies2021.difference(campanies2022)
difference2_set = campanies2022.difference(campanies2021)
intersection_set = campanies2021.intersection(campanies2022)
union_set = campanies2021.union(campanies2022)

# %%
print("差集，2021年度有進世界公司財富榜頭1000名但沒進2022年度的公司有：",difference_set)
# Out:
# 差集，2021年度有進世界公司財富榜頭1000名但沒進2022年度的公司有： {'Laureate Education', 'Mednax', 'TCF Financial', 'EchoStar', 'Colfax', 'B&G Foods', 'BGC Partners', 'Magellan Health', 'Seagen', 'Cooper', 'Navistar International', 'Zurn Water Solutions', 'Covanta Holding', 'International Business Machines', 'BioMarin Pharmaceutical', 'Sempra Energy', 'Synovus Financial', 'Hilltop Holdings', 'Scientific Games', 'Revlon', 'Triumph Group', 'CDK Global', 'CoreLogic', 'F5 Networks', 'Air Lease', 'Amneal Pharmaceuticals', 'Hexion', 'Discovery', 'Alliance Data Systems', 'Greenbrier', 'Itron', 'CIT Group', 'Blackstone Group', 'Kansas City Southern', 'Lululemon Athletica', 'Alexion Pharmaceuticals', 'Hain Celestial Group', 'CoreCivic', 'Core-Mark Holding', 'Michaels', 'Meredith', 'Crane', 'Echo Global Logistics', 'BOK Financial', 'Arcosa', 'ViacomCBS', 'United Parcel Service', 'Terminix Global Holdings', 'Windstream Holdings II', 'Kennametal', 'First Citizens BancShares', 'Unisys', 'PRA Health Sciences', 'Teledyne FLIR', 'Vail Resorts', 'PAE', 'HollyFrontier', 'Genesis Healthcare', 'Carpenter Technology', 'Westlake Chemical', 'Univision Communications', "People's United Financial", 'Korn Ferry', 'Universal', 'Archer Daniels Midland (ADM)', 'American International Group', 'Clearwater Paper', 'Triple-S Management', 'Healthpeak Properties', 'ContextLogic', 'PPD', 'Varian Medical Systems', 'StoneX', 'Trinity Industries', 'Perspecta', 'Mahwah Bergen Retail Group', 'Flagstar Bancorp', 'AAR', 'Edgewell Personal Care', 'Cooper Tire & Rubber', 'Enable Midstream Partners', 'Modine Manufacturing'}

# %%
print("差集，2022年度有進世界公司財富榜頭1000名但沒進2021年度的公司有：",difference2_set)
# Out:
# 差集，2022年度有進世界公司財富榜頭1000名但沒進2021年度的公司有： {'Sempra', 'Spirit Airlines', 'GXO Logistics', 'eXp World Holdings', 'Coinbase Global', 'Schnitzer Steel Industries', 'Etsy', 'Mutual of America Life Insurance', 'Crocs', 'Hilton Grand Vacations', 'Concentrix', 'Jackson Financial', 'Host Hotels & Resorts', 'Cowen', 'Univision Communciations', 'WeWork', 'Pure Storage', 'Saia', 'Change Healthcare', 'Enovis', 'AppLovin', 'Annaly Capital Management', 'Wolverine World Wide', 'Light & Wonder', 'Peloton Interactive', 'Arch Resources', 'SM Energy', 'Twilio', 'HF Sinclair', 'Olympic Steel', 'Archer Daniels Midland', 'Kontoor Brands', 'F5', 'Cooper Cos.', 'Ares Management', 'Blackstone', 'Callaway Golf', 'Sun Communities', 'CrossAmerica Partners', 'TPG', 'Dun & Bradstreet Holdings', 'Atkore', 'Westlake', 'Genesis Energy', 'Alight', 'Element Solutions', 'Paramount Global', 'IBM', 'Vizio Holding', 'UPS', 'Century Aluminum', 'Signature Bank', 'AMC Entertainment Holdings', 'New Residential Investment', "Victoria's Secret", 'Crane Holdings', 'Core & Main', 'Encore Wire', 'Kaiser Aluminum', 'Party City Holdco', 'Roku', 'Mattress Firm Group', 'Lululemon athletica', 'Pinterest', 'Marvell Technology', 'Genesco', 'Liberty Energy', 'AdaptHealth', 'DocuSign', 'Moderna', 'TrueBlue', 'Bread Financial Holdings', 'AIG', '1-800-Flowers.com', 'StoneX Group', 'Acushnet Holdings', 'Alpha Metallurgical Resources', 'Vroom', 'Warner Bros. Discovery', 'Coterra Energy', 'Vista Outdoor', 'Bright Health Group'}

# %%
print("交集，2021及2022年度均有進世界公司財富榜頭1000名的公司有：",intersection_set)
# Out:
# 交集，2021及2022年度均有進世界公司財富榜頭1000名的公司有： {'ARKO', 'EnLink Midstream', 'Vontier', 'Brighthouse Financial', 'DISH Network', 'Bath & Body Works', 'American Express', 'Pfizer', 'Deere', 'Plexus', 'Whirlpool', 'Pioneer Natural Resources', 'Jabil', 'Boise Cascade', 'Albertsons', 'Lennar', 'Performance Food Group', 'West Pharmaceutical Services', 'Kar Auction Services', 'Under Armour', 'MetLife', 'Phillips 66', 'Lincoln National', 'Micron Technology', 'Playtika Holding', 'MGM Resorts International', 'NiSource', 'Toro', 'Granite Construction', 'Newmark Group', 'Lyft', 'AmerisourceBergen', 'IAC/InterActiveCorp', 'Diebold Nixdorf', 'First Republic Bank', 'Sentry Insurance Group', 'Sonoco Products', 'Navient', 'Stewart Information Services', 'Western Midstream Partners', 'loanDepot', 'Terex', 'Sleep Number', 'Resolute Forest Products', 'Brunswick', 'Spirit AeroSystems Holdings', 'U.S. Bancorp', 'JELD-WEN Holding', 'Conagra Brands', 'Darden Restaurants', 'Sprague Resources', 'Avient', 'BWX Technologies', 'Bank of New York Mellon', 'Kroger', 'Stanley Black & Decker', 'Maximus', 'Icahn Enterprises', 'Schneider National', 'Spire', 'Nvidia', 'Graphic Packaging Holding', 'Stifel Financial', 'General Electric', 'PriceSmart', 'Norfolk Southern', 'IDEXX Laboratories', 'Garrett Motion', 'ManTech International', 'Voya Financial', 'Sally Beauty Holdings', 'Reinsurance Group of America', 'Brookdale Senior Living', 'New Jersey Resources', 'Cintas', 'WestRock', 'Centene', 'Caesars Entertainment', 'Intel', 'McCormick', 'Deckers Outdoor', 'Albemarle', 'Central Garden & Pet', 'Becton Dickinson', 'Dycom Industries', 'Discover Financial Services', 'Kelly Services', 'Digital Realty Trust', 'Hanover Insurance Group', 'Tempur Sealy International', 'S&P Global', 'Fidelity National Information Services', 'Valhi', 'Microchip Technology', 'Tractor Supply', 'CBRE Group', 'Vertex Pharmaceuticals', 'Costco Wholesale', 'MYR Group', 'Colgate-Palmolive', 'Patrick Industries', 'Ameren', 'Curtiss-Wright', 'Stericycle', 'PayPal Holdings', 'Edwards Lifesciences', 'Pacific Life', 'Regal Rexnord', 'Pinnacle West Capital', 'Newell Brands', 'Graybar Electric', 'Ball', 'Xerox Holdings', 'Chevron', "Moody's", 'Regeneron Pharmaceuticals', 'Copart', 'Teledyne Technologies', 'Fiserv', 'Fluor', "Dillard's", 'Cleveland-Cliffs', 'KBR', 'Hormel Foods', 'Fortive', 'C.H. Robinson Worldwide', 'Chewy', 'Skechers U.S.A.', 'General Dynamics', 'Amazon', 'Autodesk', 'Flowserve', 'Kirby', 'Benchmark Electronics', 'Mastercard', 'Franchise Group', 'Take-Two Interactive Software', 'Laboratory Corp. of America', 'Ensign Group', 'Puget Energy', 'Interpublic Group', 'Qurate Retail', 'Service Corp. International', 'Applied Industrial Technologies', 'Merck', 'Oneok', 'Sherwin-Williams', 'Pool', 'Cerner', 'Tenneco', 'Teradyne', 'Eli Lilly', 'Principal Financial', 'Bed Bath & Beyond', 'Electronic Arts', 'American Water Works', 'Viatris', 'First Solar', 'CUNA Mutual Group', 'Johnson & Johnson', 'Marathon Oil', 'Mondelez International', 'Nike', 'Zoetis', 'Marriott International', 'BorgWarner', 'Toll Brothers', 'McKesson', 'Aramark', 'Beacon Roofing Supply', 'Ally Financial', 'Abbott Laboratories', 'MDC Holdings', 'Broadridge Financial Solutions', 'Starbucks', 'Freddie Mac', 'Tapestry', 'UFP Industries', 'Visa', 'Leidos Holdings', 'Elanco Animal Health', 'PulteGroup', 'AT&T', 'ConocoPhillips', 'Group 1 Automotive', 'McAfee', 'Carvana', 'Eastman Chemical', 'Old Republic International', 'Rockwell Automation', 'Dentsply Sirona', 'Keysight Technologies', 'KKR', 'Academy Sports and Outdoors', 'Community Health Systems', 'SBA Communications', 'Hess', 'Constellation Brands', 'Coca-Cola', 'Patterson', 'Envista Holdings', 'Valvoline', 'Entegris', 'MKS Instruments', 'Tetra Tech', 'Dropbox', 'Xylem', 'Oshkosh', 'Diamondback Energy', 'Simon Property Group', 'Resideo Technologies', 'Nexstar Media Group', 'Continental Resources', 'TravelCenters of America', 'Endeavor Group Holdings', 'Boeing', 'Bristol-Myers Squibb', 'Cardinal ...

# %%
print("聯集，2021或2022年度有進世界公司財富榜頭1000名的公司有：",intersection_set)
# Out:
# 聯集，2021或2022年度有進世界公司財富榜頭1000名的公司有： {'ARKO', 'EnLink Midstream', 'Vontier', 'Brighthouse Financial', 'DISH Network', 'Bath & Body Works', 'American Express', 'Pfizer', 'Deere', 'Plexus', 'Whirlpool', 'Pioneer Natural Resources', 'Jabil', 'Boise Cascade', 'Albertsons', 'Lennar', 'Performance Food Group', 'West Pharmaceutical Services', 'Kar Auction Services', 'Under Armour', 'MetLife', 'Phillips 66', 'Lincoln National', 'Micron Technology', 'Playtika Holding', 'MGM Resorts International', 'NiSource', 'Toro', 'Granite Construction', 'Newmark Group', 'Lyft', 'AmerisourceBergen', 'IAC/InterActiveCorp', 'Diebold Nixdorf', 'First Republic Bank', 'Sentry Insurance Group', 'Sonoco Products', 'Navient', 'Stewart Information Services', 'Western Midstream Partners', 'loanDepot', 'Terex', 'Sleep Number', 'Resolute Forest Products', 'Brunswick', 'Spirit AeroSystems Holdings', 'U.S. Bancorp', 'JELD-WEN Holding', 'Conagra Brands', 'Darden Restaurants', 'Sprague Resources', 'Avient', 'BWX Technologies', 'Bank of New York Mellon', 'Kroger', 'Stanley Black & Decker', 'Maximus', 'Icahn Enterprises', 'Schneider National', 'Spire', 'Nvidia', 'Graphic Packaging Holding', 'Stifel Financial', 'General Electric', 'PriceSmart', 'Norfolk Southern', 'IDEXX Laboratories', 'Garrett Motion', 'ManTech International', 'Voya Financial', 'Sally Beauty Holdings', 'Reinsurance Group of America', 'Brookdale Senior Living', 'New Jersey Resources', 'Cintas', 'WestRock', 'Centene', 'Caesars Entertainment', 'Intel', 'McCormick', 'Deckers Outdoor', 'Albemarle', 'Central Garden & Pet', 'Becton Dickinson', 'Dycom Industries', 'Discover Financial Services', 'Kelly Services', 'Digital Realty Trust', 'Hanover Insurance Group', 'Tempur Sealy International', 'S&P Global', 'Fidelity National Information Services', 'Valhi', 'Microchip Technology', 'Tractor Supply', 'CBRE Group', 'Vertex Pharmaceuticals', 'Costco Wholesale', 'MYR Group', 'Colgate-Palmolive', 'Patrick Industries', 'Ameren', 'Curtiss-Wright', 'Stericycle', 'PayPal Holdings', 'Edwards Lifesciences', 'Pacific Life', 'Regal Rexnord', 'Pinnacle West Capital', 'Newell Brands', 'Graybar Electric', 'Ball', 'Xerox Holdings', 'Chevron', "Moody's", 'Regeneron Pharmaceuticals', 'Copart', 'Teledyne Technologies', 'Fiserv', 'Fluor', "Dillard's", 'Cleveland-Cliffs', 'KBR', 'Hormel Foods', 'Fortive', 'C.H. Robinson Worldwide', 'Chewy', 'Skechers U.S.A.', 'General Dynamics', 'Amazon', 'Autodesk', 'Flowserve', 'Kirby', 'Benchmark Electronics', 'Mastercard', 'Franchise Group', 'Take-Two Interactive Software', 'Laboratory Corp. of America', 'Ensign Group', 'Puget Energy', 'Interpublic Group', 'Qurate Retail', 'Service Corp. International', 'Applied Industrial Technologies', 'Merck', 'Oneok', 'Sherwin-Williams', 'Pool', 'Cerner', 'Tenneco', 'Teradyne', 'Eli Lilly', 'Principal Financial', 'Bed Bath & Beyond', 'Electronic Arts', 'American Water Works', 'Viatris', 'First Solar', 'CUNA Mutual Group', 'Johnson & Johnson', 'Marathon Oil', 'Mondelez International', 'Nike', 'Zoetis', 'Marriott International', 'BorgWarner', 'Toll Brothers', 'McKesson', 'Aramark', 'Beacon Roofing Supply', 'Ally Financial', 'Abbott Laboratories', 'MDC Holdings', 'Broadridge Financial Solutions', 'Starbucks', 'Freddie Mac', 'Tapestry', 'UFP Industries', 'Visa', 'Leidos Holdings', 'Elanco Animal Health', 'PulteGroup', 'AT&T', 'ConocoPhillips', 'Group 1 Automotive', 'McAfee', 'Carvana', 'Eastman Chemical', 'Old Republic International', 'Rockwell Automation', 'Dentsply Sirona', 'Keysight Technologies', 'KKR', 'Academy Sports and Outdoors', 'Community Health Systems', 'SBA Communications', 'Hess', 'Constellation Brands', 'Coca-Cola', 'Patterson', 'Envista Holdings', 'Valvoline', 'Entegris', 'MKS Instruments', 'Tetra Tech', 'Dropbox', 'Xylem', 'Oshkosh', 'Diamondback Energy', 'Simon Property Group', 'Resideo Technologies', 'Nexstar Media Group', 'Continental Resources', 'TravelCenters of America', 'Endeavor Group Holdings', 'Boeing', 'Bristol-Myers Squibb', 'Cardinal  ...
